# %% [markdown]
# <a href="https://colab.research.google.com/github/ssrishti582/6Companies30Days/blob/main/placement.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-bbd098fa-72e4-40d7-abde-366611d3274e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bbd098fa-72e4-40d7-abde-366611d3274e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('placement.csv')
print(df)
# Out:
#     Unnamed: 0  cgpa     iq  placement
# 0            0   6.8  123.0          1
# 1            1   5.9  106.0          0
# 2            2   5.3  121.0          0
# 3            3   7.4  132.0          1
# 4            4   5.8  142.0          0
# ..         ...   ...    ...        ...
# 95          95   4.3  200.0          0
# 96          96   4.4   42.0          0
# 97          97   6.7  182.0          1
# 98          98   6.3  103.0          1
# 99          99   6.2  113.0          1
#
# [100 rows x 4 columns]

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
df=df.iloc[ : ,1 : ]
#indexing

# %%
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %%
#steps

# 0. preprocess + EDA + feature selection
# 1. extract input and output cols
# 2. Scale the values
# 3. train test values
# 4. train the model
# 5. Evaluate the model/model selection
# 6. Deploy the model

# %%
df.tail()
# Out:
#     cgpa     iq  placement
# 95   4.3  200.0          0
# 96   4.4   42.0          0
# 97   6.7  182.0          1
# 98   6.3  103.0          1
# 99   6.2  113.0          1

# %%
df.shape
# Out:
# (100, 3)

# %%
df.isnull()
# Out:
#      cgpa     iq  placement
# 0   False  False      False
# 1   False  False      False
# 2   False  False      False
# 3   False  False      False
# 4   False  False      False
# ..    ...    ...        ...
# 95  False  False      False
# 96  False  False      False
# 97  False  False      False
# 98  False  False      False
# 99  False  False      False
#
# [100 rows x 3 columns]

# %%
df.isnull().sum()
# Out:
# cgpa         0
# iq           0
# placement    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   cgpa       100 non-null    float64
#  1   iq         100 non-null    float64
#  2   placement  100 non-null    int64
# dtypes: float64(2), int64(1)
# memory usage: 2.5 KB

# %%
df.describe()
# Out:
#              cgpa          iq   placement
# count  100.000000  100.000000  100.000000
# mean     5.991000  123.580000    0.500000
# std      1.143634   39.944198    0.502519
# min      3.300000   37.000000    0.000000
# 25%      5.075000  101.500000    0.000000
# 50%      6.000000  127.500000    0.500000
# 75%      6.900000  149.000000    1.000000
# max      8.500000  233.000000    1.000000

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
plt.scatter(df['cgpa'],df['iq'],c=df['placement'])

# %%
#now we have to make such ML model jo data ke andar chupe huee pattern ko samjh pae

# %%
#logistic regression -jo data ko classify krta hai

# %%
#search line which separate two different type of data point

# %%
#now we will do feature selection

# %%
#independent-cgpa, iq and dependent placement

# %%
x=df.iloc[ : ,0:2]
y=df.iloc[ : ,-1]
# -1 for selecting last column

# %%
x
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
y
# Out:
# 0     1
# 1     0
# 2     0
# 3     1
# 4     0
#      ..
# 95    0
# 96    0
# 97    1
# 98    1
# 99    1
# Name: placement, Length: 100, dtype: int64

# %%
#we will do scaling after train test split

# %%
y.shape
# Out:
# (100,)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1)
#x-independent variable
#y-dependent variable
#test me 10 % of data jaega
#and training me rest 90% of data jaega

# %%
x_train
# Out:
#     cgpa     iq
# 97   6.7  182.0
# 16   5.2  224.0
# 4    5.8  142.0
# 15   5.1  176.0
# 11   6.9  138.0
# ..   ...    ...
# 80   4.9  196.0
# 79   6.5   90.0
# 55   7.8  114.0
# 59   4.8  112.0
# 90   7.3   86.0
#
# [90 rows x 2 columns]

# %%
x_test
# Out:
#     cgpa     iq
# 95   4.3  200.0
# 5    7.1   48.0
# 8    6.1  156.0
# 43   6.8  141.0
# 44   7.5   61.0
# 46   5.3  114.0
# 62   6.0  102.0
# 24   4.7  121.0
# 31   3.9  109.0
# 85   5.8  166.0

# %%
y_train
# Out:
# 97    1
# 16    0
# 4     0
# 15    0
# 11    1
#      ..
# 80    0
# 79    1
# 55    1
# 59    0
# 90    1
# Name: placement, Length: 90, dtype: int64

# %%
y_test
# Out:
# 95    0
# 5     1
# 8     0
# 43    1
# 44    1
# 46    0
# 62    0
# 24    0
# 31    0
# 85    1
# Name: placement, dtype: int64

# %%
#scale krna hai -1 se 1 ke bich me

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
x_train=scaler.fit_transform(x_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-91fabdcaa71d> in <cell line: 1>()
# ----> 1 x_train=scaler.fit_transform(x_train)
#
# NameError: name 'scaler' is not defined

# %%
x_train
# Out:
# array([[ 0.6013588 ,  1.48387754],
#        [-0.72084703,  2.55430828],
#        [-0.1919647 ,  0.46441969],
#        [-0.80899409,  1.33095886],
#        [ 0.77765291,  0.3624739 ],
#        [-0.63269998, -0.07079568],
#        [ 0.68950586, -0.86087552],
#        [-0.28011175,  1.15255374],
#        [-0.89714114, -1.54900957],
#        [-0.72084703,  0.20955522],
#        [-0.01567059, -1.47255023],
#        [-0.01567059,  0.00566365],
#        [ 0.86579997, -0.3001737 ],
#        [-0.89714114, -0.83538907],
#        [ 0.77765291,  0.38796035],
#        [-0.9852882 ,  0.79574349],
#        [ 0.07247647, -0.52955172],
#        [ 0.16062352, -0.27468725],
#        [ 1.83541758,  0.64282481],
#        [ 0.86579997, -1.52352312],
#        [ 0.24877058,  0.10760944],
#        [ 1.21838819,  0.20955522],
#        [ 0.42506469,  0.15858233],
#        [ 0.42506469,  0.92317572],
#        [-0.72084703,  0.94866217],
#        [-0.72084703, -0.35114659],
#        [-1.42602348, -2.08422494],
# ...

# %%
x_test=scaler.transform(x_test)

# %%
x_test
# Out:
# array([[-1.51417053,  1.94263357],
#        [ 0.95394702, -1.93130626],
#        [ 0.07247647,  0.82122993],
#        [ 0.68950586,  0.43893324],
#        [ 1.30653525, -1.59998246],
#        [-0.63269998, -0.24920081],
#        [-0.01567059, -0.55503816],
#        [-1.16158231, -0.07079568],
#        [-1.86675876, -0.37663304],
#        [-0.1919647 ,  1.0760944 ]])

# %%
#model ko train krna hai

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression()

# %%
clf.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-23a7f0d6d621> in <cell line: 1>()
# ----> 1 clf.fit(x_train,y_train)
#
# NameError: name 'x_train' is not defined

# %%
#model training

# %%
clf.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
clf.predict(x_test)
# Out:
# array([0, 1, 1, 1, 1, 0, 1, 0, 0, 0])

# %%
y_test
# Out:
# 95    0
# 5     1
# 8     0
# 43    1
# 44    1
# 46    0
# 62    0
# 24    0
# 31    0
# 85    1
# Name: placement, dtype: int64

# %%
y_pred=clf.predict(x_test)

# %%
y_pred
# Out:
# array([0, 1, 1, 1, 1, 0, 1, 0, 0, 0])

# %%
y_test
# Out:
# 95    0
# 5     1
# 8     0
# 43    1
# 44    1
# 46    0
# 62    0
# 24    0
# 31    0
# 85    1
# Name: placement, dtype: int64

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.7

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x_train,y_train.values,clf=clf, legend=2)
# Out:
# <Axes: >

# %%
import pickle
#object ko file me convert krta hai and usko kisi bhi aur environment me use kr skta hu

# %%
pickle.dump(clf,open('model.pkl','wb'))
